# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Ahmed Zubeyr Terzi__
# Bachelor's degree in management

# %% [markdown]
# _I am interested in data science because I want to handle with complex and messy data and extract objective result from it_

# %% [markdown]
# ### my code will sum up x and y variables

# %%
x, y = 13, 7
x + y
# Out:
# 20

# %% [markdown]
#  1- Optimal Learning Stress Environment
#  2- Strong Focus on Python Applications
#  3- Rigorous Relevant Content
#  4- Flexible Self-paced Exercises
#  5- Good Career Credentials
#  6- Emphasis On Data Projects
#  7- Wide Exposure to Data Science Skills
#  ***
#  https://anyinstructor.com/ibm-data-science-certificate-reasons/
